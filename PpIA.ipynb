# %% [markdown]
# <a href="https://colab.research.google.com/github/abiud2emiliano-sudo/PPIA/blob/main/PpIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Esté es mi primer notebook

# %%
import pandas as pd
import numpy as pd
import matplotlib.pyplot as plt
DATA URL = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
# Out:
#   File "/tmp/ipykernel_380/4028499320.py", line 4
#     DATA URL = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
#          ^
# SyntaxError: invalid syntax
