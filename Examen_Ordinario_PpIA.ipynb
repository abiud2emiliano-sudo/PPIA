# %% [markdown]
# <a href="https://colab.research.google.com/github/abiud2emiliano-sudo/PPIA/blob/main/Examen_Ordinario_PpIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Abiud Emiliano Perez Palos
# N-1 / 25-05-26
# Programacion Para Inteligencia Artificial
# Examen Ordinario

# %% [markdown]
# # **Seccion I Responder Preguntas**

# %% [markdown]
# Pregunta 1
# c)
# Pregunta 2
# b)
# Pregunta 3
# b)
# Pregunta 4
# a)
# Pregunta 5
# b)
# Pregunta 6
# a)

# %% [markdown]
# **Seccion** II Resolver Problema

# %% [markdown]
# PREGUNTA 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score

# %%
wine = load_wine()

df = pd.DataFrame(wine.data, columns=wine.feature_names)

df['target'] = wine.target

print("Primeras filas del dataset:")
print(df.head())
# Out:
# Primeras filas del dataset:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
# ...

# %% [markdown]
# PREGUNTA 2

# %%
primera_columna = df.columns[0]

df.loc[0:4, primera_columna] = np.nan

print("\nCantidad de NaN antes de imputar:")
print(df.isnull().sum())
# Out:
# Cantidad de NaN antes de imputar:
# alcohol                         5
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64

# %%
media = df[primera_columna].mean()

df[primera_columna] = df[primera_columna].fillna(media)

print("\nValores nulos después de la imputación:")
print(df.isnull().sum())
# Out:
# Valores nulos después de la imputación:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64

# %% [markdown]
# PREGUNTA 3

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = df[wine.feature_names]
y = df["target"]

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)


X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.25,
    random_state=42
)

# %% [markdown]
# PREGUNTA 4

# %%
print("Tamaño de entrenamiento:", X_train.shape)
print("Tamaño de prueba:", X_test.shape)
# Out:
# Tamaño de entrenamiento: (133, 13)
# Tamaño de prueba: (45, 13)

# %% [markdown]
# PREGUNTA 5

# %%
print("\nExactitud del modelo:")
print(f"Accuracy = {accuracy:.4f}")
# Out:
# Exactitud del modelo:
# Accuracy = 0.9556

# %% [markdown]
# PREGUNTA 6

# %%
plt.figure(figsize=(20,15))

plot_tree(
    modelo,
    feature_names=wine.feature_names,
    class_names=wine.target_names,
    filled=True
)

plt.title("Árbol de Decisión - Dataset Wine")
plt.savefig("decision_tree.png", dpi=300)
plt.show()

# %% [markdown]
# PREGUNTA 7

# %%
raiz = wine.feature_names[modelo.tree_.feature[0]]

print("\nCaracterística utilizada en el nodo raíz:")
print(raiz)
# Out:
# Característica utilizada en el nodo raíz:
# color_intensity

# %% [markdown]
# ¿Que indica esto sobre la importancia de dicho quimico para la clasificacion de los vinos?
#
# R= La considero las mas importante para realizar las primeras separaciones en el arbol de decision, esto me ayuda de la manera mas optima diferenciar los tipos de vinos implementados en el dataset y que da entender que el atributo quimico es el mejor al reducir la impuresa de estos.
